# %%
import lightkurve as lk
import astropy.table as astab
import pandas as pd
import numpy as np
import astropy
from astropy.coordinates import SkyCoord
from astropy import units as u
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from tqdm import tqdm
# %pylab inline
# pylab.rcParams['figure.figsize'] = (16, 8)
import warnings
import astropy.table as astab
from astropy.io import fits

warnings.filterwarnings('ignore',
    message="WARNING (theano.tensor.opt): Cannot construct a scalar test value from a test value with no size:"
)

import pymc3 as pm
import pymc3_ext as pmx
import aesara_theano_fallback.tensor as tt
from celerite2.theano import terms, GaussianProcess
import exoplanet as xo

import arviz as az
from corner import corner

from scipy.signal import savgol_filter

print(astropy.__version__)
print(lk.__version__)
# %matplotlib widget
dd = "/Users/kjaehnig/CCA_work/GAT/"
# Out:
# 4.3.1
# 2.0.10

# %% [markdown]
# # LOAD IN ALLVISIT FILE (an absolute unit: ~ 2.75GB)

# %%
allvis17 = astab.Table.read("/Users/kjaehnig/CCA_work/GAT/dr17_joker/allVisit-dr17-synspec.fits",hdu=1, format='fits')
print(len(allvis17['APOGEE_ID']))
print(allvis17.columns)
hq_jk_allstar_tess_edr3 = astab.Table.read(dd+'dr17_joker/unimodal_joker_sample_joined_w_tess_edr3_REDUX.fits', format='fits')
# Out:
# 2659178
# <TableColumns names=('APOGEE_ID','TARGET_ID','VISIT_ID','FILE','FIBERID','CARTID','PLATE','MJD','TELESCOPE','SURVEY','FIELD','PROGRAMNAME','ALT_ID','LOCATION_ID','RA','DEC','GLON','GLAT','RELFLUX','MTPFLUX','J','J_ERR','H','H_ERR','K','K_ERR','SRC_H','WASH_M','WASH_M_ERR','WASH_T2','WASH_T2_ERR','DDO51','DDO51_ERR','IRAC_3_6','IRAC_3_6_ERR','IRAC_4_5','IRAC_4_5_ERR','IRAC_5_8','IRAC_5_8_ERR','IRAC_8_0','IRAC_8_0_ERR','WISE_4_5','WISE_4_5_ERR','TARG_4_5','TARG_4_5_ERR','WASH_DDO51_GIANT_FLAG','WASH_DDO51_STAR_FLAG','PMRA','PMDEC','PM_SRC','AK_TARG','AK_TARG_METHOD','AK_WISE','SFD_EBV','APOGEE_TARGET1','APOGEE_TARGET2','APOGEE_TARGET3','APOGEE_TARGET4','TARGFLAGS','SNR','STARFLAG','STARFLAGS','DATEOBS','JD','VLSR','VGSR','CHISQ','SYNTHFILE','MIN_H','MAX_H','MIN_JK','MAX_JK','VREL','VRELERR','VHELIO','BC','RV_TEFF','RV_LOGG','RV_FEH','RV_CARB','RV_ALPHA','XCORR_VREL','XCORR_VRELERR','XCORR_VHELIO','CCFWHM','AUTOFWHM','RV_CHI2','N_COMPONENTS','RV_COMPONENTS','RV_FLAG')>

# %%
all_seps = np.ones(len(hq_jk_allstar_tess_edr3))
for ii,aID in enumerate(tqdm(hq_jk_allstar_tess_edr3["APOGEE_ID"])):
    ra1,dec1 = hq_jk_allstar_tess_edr3[ii]['ra'],hq_jk_allstar_tess_edr3[ii]['dec']
    ra2,dec2 = hq_jk_allstar_tess_edr3[ii]['RA'],hq_jk_allstar_tess_edr3[ii]['DEC']
    coord1 = SkyCoord(ra=ra1,dec=dec1,unit=u.deg,frame='icrs')
    coord2 = SkyCoord(ra=ra2,dec=dec2,unit=u.deg,frame='icrs')
    seps = coord1.separation(coord2).to(u.mas).value
    all_seps[ii] = seps
# Out:
# 100%|██████████████████████████████████████| 1741/1741 [00:03<00:00, 557.04it/s]

# %%
fig,ax = plt.subplots(figsize=(10,5))
cnts = ax.hist((all_seps/1000.),bins='auto')
ax.set_xlabel("Separation (DR17,EDR3) ['']", fontsize=14)
# Out:
# Text(0.5, 0, "Separation (DR17,EDR3) ['']")

# %% [markdown]
# #### Load in relevant cross-matches and grab Joker Params for specific TIC ID

# %%
#### DEFINE THE RV,RV_ERRs, and X_RVs for later use in the mcmc... DO NOT REDEFINE ME OR YOU MAKE PYMC3 SAD
def plot_apogee_rv_curve_with_xmatched_tic_id(target_tic='TIC 20215452', writeout_fits=False):
#     target_tic = 'TIC 20215452'

    #cross-matched star table (has source_id, apogee_id, TIC_id)
    hq_jk_allstar_tess_edr3 = astab.Table.read(dd+'dr17_joker/unimodal_joker_sample_joined_w_tess_edr3_REDUX.fits', format='fits')

    #Adrian's calibrated RV_ERRs
    calibverr = astab.Table.read(dd+'dr17_joker/allVisit-dr17-synspec-min3-calibverr.fits', format='fits', hdu=1)
#     print(calibverr.info)
    # Grab cross-match IDs
    jk_row = hq_jk_allstar_tess_edr3[hq_jk_allstar_tess_edr3['ID'] == int(target_tic.split(' ')[1])]


    sysapodat = allvis17[allvis17['APOGEE_ID'] == jk_row['APOGEE_ID']]

    
    ## joining calib RV_ERRs with the RVs
    sysapodat = astab.join(sysapodat, calibverr['VISIT_ID','CALIB_VERR'], keys=('VISIT_ID','VISIT_ID'))
    
    if writeout_fits:
        sysapodat['VISIT_ID','JD','VHELIO','CALIB_VERR'].write(dd+f"dr17_joker/{target_tic.replace(' ','_')}_apogee_dr17_rvs.fits",format='fits')
#     print(calibverr.info, sysapodat.columns)
    x_rv = sysapodat['JD'] 
    xrv_sorted_ind = np.argsort(x_rv)

    x_rv = x_rv[xrv_sorted_ind]
    y_rv = sysapodat['VHELIO'][xrv_sorted_ind]
    yerr_rv = sysapodat['CALIB_VERR'][xrv_sorted_ind]

    map_t0_bmjd = jk_row['MAP_t0_bmjd']
    t0_bmjd = astropy.time.Time(map_t0_bmjd, format='mjd', scale='tcb')
    t0_bjd = t0_bmjd.tcb.jd

    fit,ax = plt.subplots(nrows=1, figsize=(15,8))

    ax.scatter(((x_rv -t0_bjd + 0.5*jk_row['MAP_P']) % jk_row['MAP_P']) - 0.5 * jk_row['MAP_P'], y_rv)

    ax.axhline(0.0,ls='--')
    ax.axvline(0.0,ls='--')
    return sysapodat, jk_row, (x_rv,y_rv,yerr_rv), ax

visdata,jk_row,rvdat, _ = plot_apogee_rv_curve_with_xmatched_tic_id(writeout_fits=False)
# print(jk_row['MAP_v0'], sysapodat['VHELIO'])

# %%
x_rv, y_rv, yerr_rv = rvdat

# %% [markdown]
# ### Load TESS data for the APOGEE TARGET (there may not be any (yay!))

# %%
target_tic = 'TIC 20215452'
target_lk = lk.search_lightcurve(target_tic,
             mission='TESS',
            author='SPOC',
             )
print(target_lk)
# unpro_lks = target_lk.download_all()
# lks = unpro_lks.stitch(corrector_func=lambda x: x.remove_nans().normalize().flatten())
lks = target_lk.download_all().stitch().remove_nans()
lks.plot()
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 24 2020   SPOC     120    20215452      0.0
# WARNING: dropping mask in Quantity column 'flux': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'flux_err': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'centroid_col': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'centroid_row': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'sap_flux': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'sap_flux_err': masked Quantity not supported [astropy.table.table]
# ...

# %%
# lks = ppt_flux.remove_nans()  #[lks.remove_nans()]
# lks = lks.remove_outliers(sigma_lower=10**6)
# period_grid = np.exp(np.linspace(np.log(0.1), np.log(100),1000))

flat = lks.flatten()
star1_bls = flat.to_periodogram('bls')

star1_per = star1_bls.period_at_max_power
star1_t0 = star1_bls.transit_time_at_max_power
star1_dur = star1_bls.duration_at_max_power
star1_depth = star1_bls.depth_at_max_power

fig,ax = plt.subplots(nrows=2,figsize=(10,12))

bls_power = star1_bls.power
bls_per = star1_bls.period
ax[0].plot(bls_per,bls_power)

ind = np.argmax(bls_power)
period = bls_per[ind].value
t0 = star1_bls.transit_time[ind].value

def fold(x, period, t0):
    hp = 0.5 * period
    return (x - t0 + hp) % period - hp

print(f"bls: {star1_t0},manual: {t0}")

from matplotlib import cm
x = lks.time.value
y = lks.flux.value
ax[1].scatter(fold(x, star1_per.value, star1_t0.value), y, c=x, cmap=cm.plasma, s=5)
ax[1].plot(fold(x, period, t0), y, ',k')
ax[1].axvline(0.0, ls='--')
# Out:
# bls: 1956.2991026548211,manual: 1956.2991026548211

# %%
flat_x = flat.time.value
flat_y = flat.flux.value

from astropy.timeseries import bls

periodogram = bls.BoxLeastSquares(flat_x,flat_y)
res = periodogram.autopower(0.1)

bls_ind = np.argmax(res['power'])
bls_period = res['period'][bls_ind]
bls_t0 = res['transit_time'][bls_ind]
print(bls_period, bls_t0)
plt.plot(res["period"], res["power"])
plt.axvline(bls_period, c='C5')
# Out:
# 0.5957251304674985 1956.2691026548212

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax.scatter(fold(x, period, t0), y, c=x, s=3)
ax.scatter(fold(x, period, t0) + period, y, c=x, s=3)
ax.scatter(fold(x, period, t0) - period, y, c=x, s=3)
ax.axvline(0, c="k", lw=0.5)
ax.axvline(0.5 * period, c="k", lw=0.5)
ax.axvline(-0.5 * period, c="k", lw=0.5)
ax.set_xlim(-period, period)
ax.set_ylabel("flux")
ax.set_xlabel("time since eclipse");

# %%
with fits.open(dd+"/dr17_joker/TIC_20215452_apogee_dr17_rvs.fits") as hdu:
    data = hdu[1].data
  
raw_x_rv = data["JD"]
raw_y_rv = data["VHELIO"]

# %%
print(raw_x_rv, period, star1_per)
# Out:
# [2456703.00812 2456706.95765 2456733.8847  2457794.97462 2457822.9392
#  2457827.91358 2457849.83508 2457800.97018 2457829.93046 2457850.87827
#  2457853.85747 2457833.90792 2457854.85109 2457914.76401] 0.5956271483513841 0.5956271483513841 d

# %%
fig,ax = plt.subplots(figsize=(17,8),ncols=2)


per1 = bls_period #0.5957251304674985# star1_per.value
t01 = bls_t0 #1956.2965581938392#star1_t0.value

K_est = 0.5 * (y_rv.max() - y_rv.min())

x_rv_fold = fold(x_rv - 2457000.0 - .5, per1, t01)

ax[0].set_title("Dan's Period and t0")
ax[0].scatter(x_rv_fold, y_rv - 0.5 * (y_rv.max() + y_rv.min()), c="k", s=10)
ax[0].scatter(x_rv_fold + per1, y_rv - 0.5 * (y_rv.max() + y_rv.min()), c="k", s=10)
ax[0].scatter(x_rv_fold - per1, y_rv - 0.5 * (y_rv.max() + y_rv.min()), c="k", s=10)

x0 = np.linspace(-per1, per1, 5000)
ax[0].plot(x0, -K_est * np.sin(2 * np.pi * x0 / per1), "k")
ax[0].axhline(0, c="k", lw=0.5)
ax[0].axvline(0, c="k", lw=0.5)
ax[0].axvline(0.5 * per1, c="k", lw=0.5, linestyle="dashed")
ax[0].axvline(-0.5 * per1, c="k", lw=0.5, linestyle="dashed")
ax[0].set_xlim(-per1, per1)
ax[0].set_ylabel("rv")
ax[0].set_xlabel("time since eclipse")


K_est = 0.5 * (raw_y_rv.max() - raw_y_rv.min())

period = star1_per.value
t0 = star1_t0.value

x_rv_fold = fold(raw_x_rv - 2457000.0 - 0.5, period, t0)

ax[1].set_title("Karl's Period and t0")
ax[1].scatter(x_rv_fold, raw_y_rv - 0.5 * (raw_y_rv.max() + raw_y_rv.min()), c="k", s=10)
ax[1].scatter(x_rv_fold + period, raw_y_rv - 0.5 * (raw_y_rv.max() + raw_y_rv.min()), c="k", s=10)
ax[1].scatter(x_rv_fold - period, raw_y_rv - 0.5 * (raw_y_rv.max() + raw_y_rv.min()), c="k", s=10)

x0 = np.linspace(-period, period, 5000)
ax[1].plot(x0, -K_est * np.sin(2 * np.pi * x0 / period), "k")
ax[1].axhline(0, c="k", lw=0.5)
ax[1].axvline(0, c="k", lw=0.5)
ax[1].axvline(0.5 * period, c="k", lw=0.5, linestyle="dashed")
ax[1].axvline(-0.5 * period, c="k", lw=0.5, linestyle="dashed")
ax[1].set_xlim(-period, period)
ax[1].set_ylabel("rv")
ax[1].set_xlabel("time since eclipse")


print(f"Per1: {per1} d, Per2: {period} d, Delta_P: {per1-period}, delta_p/period: {(per1-period)/per1}")
print(f"t01: {t01} d, t02: {t0} d, delta_t0: {t01-t0}")
# Out:
# Per1: 0.5957251304674985 d, Per2: 0.5956271483513841 d, Delta_P: 9.798211611444785e-05, delta_p/period: 0.00016447537816233445
# t01: 1956.2691026548212 d, t02: 1956.2991026548211 d, delta_t0: -0.029999999999972715

# %%
star1_mask = lks.create_transit_mask(period=star1_per.value, 
                                     duration=3.*star1_dur.value, 
                                     transit_time=star1_t0.value,
                                    )

# %%
period_grid = np.exp(np.linspace(np.log(0.1), np.log(100),1000))
star2_lks = lks[~star1_mask]
star2_bls = star2_lks.to_periodogram('bls',
                                period=period_grid,
                                frequency_factor = 2000, duration=np.linspace(0.001,0.09,100))
star2_per = star2_bls.period_at_max_power
star2_t0 = star2_bls.transit_time_at_max_power
star2_dur = star2_bls.duration_at_max_power
star2_depth = star2_bls.depth_at_max_power

lks_ref = min(lks.time.value)

# %%
fig,ax = plt.subplots(nrows=3, figsize=(12,8))
lks.scatter(ax=ax[0])
lks.fold(period=star1_per, epoch_time=star1_t0).scatter(ax=ax[1])
lks.fold(period=star2_per, epoch_time=star2_t0).scatter(ax=ax[2])
# Out:
# <AxesSubplot:xlabel='Phase [JD]', ylabel='Normalized Flux'>

# %%
primary_phase = lks.time.value[np.argmin(lks.flux.value)]%star1_per.value
secondary_phase = star2_lks.time.value[np.argmin(star2_lks.flux.value)]%star2_per.value
print(primary_phase, secondary_phase)
# Out:
# 0.26121623888684653 0.2576332468121514

# %% [markdown]
# #### create function for one stop LK and RV processing

# %%
def generate_folded_lightcurve_rv_data(TICid):
    
    #cross-matched star table (has source_id, apogee_id, TIC_id)
    hq_jk_allstar_tess_edr3 = astab.Table.read(dd+'dr17_joker/unimodal_joker_sample_joined_w_tess_edr3_REDUX.fits', format='fits')
#     print(hq_jk_allstar_tess_edr3.columns)

    #Adrian's calibrated RV_ERRs
    calibverr = astab.Table.read(dd+'dr17_joker/allVisit-dr17-synspec-min3-calibverr.fits', format='fits', hdu=1)

    
    # Grab cross-match IDs
    jk_row = hq_jk_allstar_tess_edr3[hq_jk_allstar_tess_edr3['ID'] == int(TICid.split(' ')[1])]

    sysapodat = allvis17[allvis17['APOGEE_ID'] == jk_row['APOGEE_ID']]

    ## joining calib RV_ERRs with the RVs
    sysapodat = astab.join(sysapodat, calibverr['VISIT_ID','CALIB_VERR'], keys=('VISIT_ID','VISIT_ID'))
        
    x_rv = sysapodat['JD'] 
    xrv_sorted_ind = np.argsort(x_rv)

    x_rv = x_rv[xrv_sorted_ind]
    y_rv = sysapodat['VHELIO'][xrv_sorted_ind]
    yerr_rv = sysapodat['CALIB_VERR'][xrv_sorted_ind]
    
    target_lk = lk.search_lightcurve(TICid,
                 mission='TESS',
                cadence='short',
                author='SPOC'
                 )
    print(target_lk)
    unpro_lks = target_lk.download_all(quality_bitmask='hardest')

    lks = unpro_lks.stitch(corrector_func=lambda x: x.remove_nans().normalize().flatten())
                           
    period_grid = np.exp(np.linspace(np.log(0.1), np.log(100),1000))
    dur_grid = np.exp(np.linspace(np.log(0.001),np.log(0.09),100))

    npts = 10**4
    pmin = period_grid.min()
    pmax = period_grid.max()
    maxtime = lks.time.max().value
    mintime = lks.time.min().value
    mindur = dur_grid.min()

    freq_f = int( ((pmin**-1 - pmax**-1) * (maxtime - mintime)**2) / (npts * mindur) ) 


    star1_bls = lks.to_periodogram('bls',
                                    period=period_grid,
                                    frequency_factor = freq_f, duration=dur_grid)
    star1_per = star1_bls.period_at_max_power
    star1_t0 = star1_bls.transit_time_at_max_power
    star1_dur = star1_bls.duration_at_max_power
    star1_depth = star1_bls.depth_at_max_power
    print(star1_per, star1_t0, star1_dur, star1_depth)
    
    x = lks.time.btjd
    y = lks.flux.value
    yerr = lks.flux_err.value
    x_lk_ref = min(x)

#     x_rv = x_rv  - 2457000 - x_lk_ref

    x = x - x_lk_ref 
    y = (y / np.median(y) - 1)

    y *= 1e3
    
    lit_t0 = star1_t0.value - x_lk_ref
    lit_period = star1_per.value
    folded_x = (x - lit_t0 + 0.5 * lit_period) % lit_period - 0.5 * lit_period
    
    map_t0_bmjd = jk_row['MAP_t0_bmjd']
    t0_bmjd = astropy.time.Time(map_t0_bmjd, format='mjd', scale='tcb')
    t0_bjd = t0_bmjd.tcb.jd


    map_folded_x_rv = ((x_rv - t0_bjd + 0.5*jk_row['MAP_P']) % jk_row['MAP_P']) - 0.5 * jk_row['MAP_P']
    
    folded_x_rv = ((x_rv - lit_t0 + 0.5 * lit_period) % lit_period) - 0.5 * lit_period
#     ((x_rv - star1_t0.tcb.jd + 0.5 * lit_period) % lit_period) - 0.5 * lit_period, y_rv, ".k")
    return ((folded_x, y),
            (folded_x_rv.value, y_rv.value - jk_row['MAP_v0'].value),
            (jk_row['MAP_P'].value,star1_per.value, jk_row['APOGEE_ID'].value),
            map_folded_x_rv)

# %%
plotdat = generate_folded_lightcurve_rv_data("TIC 20215452")
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 24 2020   SPOC     120    20215452      0.0
# WARNING: dropping mask in Quantity column 'flux': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'flux_err': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'centroid_col': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'centroid_row': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'sap_flux': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'sap_flux_err': masked Quantity not supported [astropy.table.table]
# ...

# %%
fig,ax=plt.subplots()
ax.plot(plotdat[1][0],plotdat[1][1],'.k')
ax.axvline(0.0,ls='--')
ax.axhline(0.0,ls='--')

# %%
print(plotdat[2])
tic_ids = [
    165453878,
    169820068,
    20215452,
    258108067,
    271548206,
    272074664,
    28159019,
    9429166,
    99254945
]
# Out:
# (array([3.06779099]), 0.5953533130814371, array([b'2M15091604+3602002'], dtype='|S30'))

# %%
print(len(tic_ids))
print(0%2)

tic_plotdat = [generate_folded_lightcurve_rv_data("TIC "+str(ii)) for ii in tic_ids]
# Out:
# 9
# 0
# SearchResult containing 3 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 15 2019   SPOC     120   165453878      0.0
#   1 TESS Sector 16 2019   SPOC     120   165453878      0.0
#   2 TESS Sector 22 2020   SPOC     120   165453878      0.0
# WARNING: dropping mask in Quantity column 'flux': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'flux_err': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'centroid_col': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'centroid_row': masked Quantity not supported [astropy.table.table]
# WARNING: dropping mask in Quantity column 'sap_flux': masked Quantity not supported [astropy.table.table]
# ...

# %%
fig,axes = plt.subplots(nrows=18,ncols=1, figsize=(10,100))
for ii, tic in enumerate(tic_ids):
    map_p = tic_plotdat[ii][2][0]
    bls_p = tic_plotdat[ii][2][1]
    del_p = str(np.round(map_p[0],4)) +' / ' +str(np.round(bls_p,4))
    
    frac_p = str(np.round(map_p[0]/bls_p, 2))
    
    plotdat = tic_plotdat[ii]
    axes.flatten()[ii+1*ii].plot(plotdat[0][0],plotdat[0][1],',k')
    
    axes.flatten()[ii+1*ii+1].scatter(plotdat[1][0],plotdat[1][1],label='BLS folded',c='red',s=50)
    axes.flatten()[ii+1*ii+1].scatter(plotdat[-1],plotdat[1][1],label='MAP folded',marker='+',c='black',s=100)
    axes.flatten()[ii+1*ii+1].legend(loc='best',fontsize=10)
    
    line_col = f'C{ii}'
    axes.flatten()[ii+1*ii].axvline(0.0,color=line_col,ls='--',zorder=-1)
    axes.flatten()[ii+1*ii+1].axvline(0.0,color=line_col,ls='--',zorder=-1)
    axes.flatten()[ii+1*ii+1].axhline(0.0,color=line_col,ls='--',zorder=-1)

    apoid = tic_plotdat[ii][2][2][0].decode("utf-8")
    axes.flatten()[ii+1*ii].set_title(str(apoid)+', TIC '+str(tic_ids[ii])+ r'$\ \ \ P_{map}/P_{bls} - $' + del_p+" d, [" +frac_p+']' )

# %%
for tic in tic_ids:
    plot_apogee_rv_curve_with_xmatched_tic_id('TIC '+str(tic))
